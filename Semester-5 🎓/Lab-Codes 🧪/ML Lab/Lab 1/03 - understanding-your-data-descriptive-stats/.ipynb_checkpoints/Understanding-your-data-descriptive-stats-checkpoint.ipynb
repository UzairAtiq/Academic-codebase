# %% [markdown]
# # Understanding-your-data-descriptive-stats

# %% [markdown]
# What you need to know when you first get your data

# %%
# Importing the pandas library under the alias 'pd'
import pandas as pd

# %% [markdown]
# This code segment imports the pandas library and uses it to read a CSV file named 'train.csv'. The data from the CSV file is loaded into a DataFrame named 'df', which can then be used for further analysis or manipulation.

# %%
# Reading a CSV file named 'train.csv' and storing its contents into a DataFrame called 'df'
df=pd.read_csv('train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # 1. How big is the data?

# %%
#display first 10 rows
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 176          177         0       3   Lefebre, Master. Henry Forbes    male
# 747          748         1       2           Sinkkonen, Miss. Anna  female
# 654          655         0       3    Hegarty, Miss. Hanora "Nora"  female
# 310          311         1       1  Hays, Miss. Margaret Bechstein  female
# 884          885         0       3          Sutehall, Mr. Henry Jr    male
# 248          249         1       1   Beckwith, Mr. Richard Leonard    male
# 495          496         0       3           Yousseff, Mr. Gerious    male
# 305          306         1       1  Allison, Master. Hudson Trevor    male
# 853          854         1       1       Lines, Miss. Mary Conover  female
# 66            67         1       2    Nye, Mrs. (Elizabeth Ramell)  female
#
#        Age  SibSp  Parch           Ticket      Fare    Cabin Embarked
# 176    NaN      3      1             4133   25.4667      NaN        S
# ...

# %%
#display first 10 rows
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# # 2. How does the data look like?

# %%
# random data fatch
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 592          593         0       3
# 33            34         0       2
# 305          306         1       1
# 392          393         0       3
# 329          330         1       1
# 777          778         1       3
# 715          716         0       3
# 93            94         0       3
# 749          750         0       3
# 415          416         0       3
#
#                                            Name     Sex    Age  SibSp  Parch  \
# 592                  Elsbury, Mr. William James    male  47.00      0      0
# 33                        Wheadon, Mr. Edward H    male  66.00      0      0
# 305              Allison, Master. Hudson Trevor    male   0.92      1      2
# 392                Gustafsson, Mr. Johan Birger    male  28.00      2      0
# 329                Hippach, Miss. Jean Gertrude  female  16.00      0      1
# 777               Emanuel, Miss. Virginia Ethel  female   5.00      0      0
# ...

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 55            56         1       1                      Woolner, Mr. Hugh
# 489          490         1       3  Coutts, Master. Eden Leslie "Neville"
# 517          518         0       3                      Ryan, Mr. Patrick
# 554          555         1       3                     Ohman, Miss. Velin
# 665          666         0       2                     Hickman, Mr. Lewis
#
#         Sex   Age  SibSp  Parch        Ticket    Fare Cabin Embarked
# 55     male   NaN      0      0         19947  35.500   C52        S
# 489    male   9.0      1      1    C.A. 37671  15.900   NaN        S
# 517    male   NaN      0      0        371110  24.150   NaN        Q
# 554  female  22.0      0      0        347085   7.775   NaN        S
# 665    male  32.0      2      0  S.O.C. 14879  73.500   NaN        S

# %% [markdown]
# # 3. What is the data type of cols?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # 4. Are there any missing values?

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # 5. How does the data look mathematically?

# %%
df.describe()
# only for numerical values
# anomalies can be identified through it
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # 6. Are there duplicate values?

# %%
df.duplicated().sum()
# Out:
# 0
