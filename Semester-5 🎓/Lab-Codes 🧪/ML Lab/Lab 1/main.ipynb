# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/uzair/academic-codebase📘/Semester-5 🎓/Lab-Codes 🧪/ML Lab/Lab 1/Datasets/Cleaned_data_for_model.csv', index_col=0)
df = df.sample(n=500, random_state=42)

# %%
df.head()
# Out:
#        property_type     price              location        city  baths  \
# 108845         House  11500000           Bahria Town      Lahore      3
# 21249           Flat   6500000  Gulshan-e-Iqbal Town     Karachi      2
# 124583         House     25000       Gulistan Colony  Rawalpindi      2
# 114711         House  12000000           Bahria Town      Lahore      5
# 77759          House  22000000    PIA Housing Scheme      Lahore      5
#
#          purpose  bedrooms  Area_in_Marla
# 108845  For Sale         3            5.0
# 21249   For Sale         2            4.0
# 124583  For Rent         2            7.0
# 114711  For Sale         3            5.0
# 77759   For Sale         5           10.0

# %% [markdown]
# # 1. Categorical Data

# %% [markdown]
# ## a. property_type

# %%
sns.countplot(x='property_type', data=df)
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'House'),
#   Text(1, 0, 'Flat'),
#   Text(2, 0, 'Upper Portion'),
#   Text(3, 0, 'Lower Portion'),
#   Text(4, 0, 'Penthouse'),
#   Text(5, 0, 'Farm House'),
#   Text(6, 0, 'Room')])

# %%
df['property_type'].value_counts()
# Out:
# property_type
# House            297
# Flat             125
# Upper Portion     53
# Lower Portion     21
# Penthouse          2
# Farm House         1
# Room               1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

counts = df['property_type'].value_counts()

fig, ax = plt.subplots(figsize=(10, 7))

wedges, texts, autotexts = ax.pie(
    counts,
    labels=None,
    autopct='%.2f%%',
    pctdistance=0.7
)

ax.legend(
    wedges,
    counts.index,
    title='Property Type',
    loc='center left',
    bbox_to_anchor=(1, 0.5)
)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## b. location

# %%
df['location'].value_counts().nlargest(5)
sns.countplot(x='location', data=df[df['location'].isin(df['location'].value_counts().nlargest(5).index)])
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Bahria Town'),
#   Text(1, 0, 'Gulshan-e-Iqbal Town'),
#   Text(2, 0, 'Bahria Town Karachi'),
#   Text(3, 0, 'Bahria Town Rawalpindi'),
#   Text(4, 0, 'DHA Defence')])

# %%
df['location'].value_counts()
# Out:
# location
# DHA Defence                          63
# Bahria Town Rawalpindi               29
# Bahria Town                          28
# Bahria Town Karachi                  28
# Gulshan-e-Iqbal Town                 19
#                                      ..
# Military Accounts Housing Society     1
# Janjua Town                           1
# Gosha-e-Ahbab                         1
# Baldia Town                           1
# D-12                                  1
# Name: count, Length: 160, dtype: int64

# %% [markdown]
# ## c. city

# %%
sns.countplot(x='city', data=df)
# Out:
# <Axes: xlabel='city', ylabel='count'>

# %%
df['city'].value_counts()
# Out:
# city
# Karachi       180
# Lahore        128
# Islamabad     109
# Rawalpindi     75
# Faisalabad      8
# Name: count, dtype: int64

# %% [markdown]
# ## d. purpose

# %%
sns.countplot(x='purpose', data=df)
# Out:
# <Axes: xlabel='purpose', ylabel='count'>

# %%
df['purpose'].value_counts()
# Out:
# purpose
# For Sale    360
# For Rent    140
# Name: count, dtype: int64

# %% [markdown]
# # 2. Numerical Data

# %% [markdown]
# ## a. price

# %%
plt.hist(df['price'])
# Out:
# (array([177.,  77.,  85.,  59.,  32.,  24.,  10.,  12.,  16.,   8.]),
#  array([1.60000e+04, 4.46440e+06, 8.91280e+06, 1.33612e+07, 1.78096e+07,
#         2.22580e+07, 2.67064e+07, 3.11548e+07, 3.56032e+07, 4.00516e+07,
#         4.45000e+07]),
#  <BarContainer object of 10 artists>)

# %%
sns.boxplot(df['price'])
# Out:
# <Axes: ylabel='price'>

# %%
df['price'].min()
# Out:
# np.int64(16000)

# %%
df['price'].max()
# Out:
# np.int64(44500000)

# %%
df['price'].mean()
# Out:
# np.float64(10644084.0)

# %%
df['price'].skew()
# Out:
# np.float64(1.1426806683739754)

# %% [markdown]
# ## b. baths

# %%
plt.hist(df['baths'])
# Out:
# (array([ 22., 111.,   0., 148.,   0.,  94.,  64.,   0.,  48.,  13.]),
#  array([1. , 1.6, 2.2, 2.8, 3.4, 4. , 4.6, 5.2, 5.8, 6.4, 7. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.boxplot(df['baths'])
# Out:
# <Axes: ylabel='baths'>

# %%
df['baths'].min()
# Out:
# np.int64(1)

# %%
df['baths'].max()
# Out:
# np.int64(7)

# %%
df['baths'].mean()
# Out:
# np.float64(3.526)

# %%
df['baths'].skew()
# Out:
# np.float64(0.4717208014403477)

# %% [markdown]
# ## c. bedrooms

# %%
plt.hist(df['bedrooms'])
# Out:
# (array([  3.,  12.,   0., 125.,   0., 163., 100.,   0.,  68.,  29.]),
#  array([0. , 0.6, 1.2, 1.8, 2.4, 3. , 3.6, 4.2, 4.8, 5.4, 6. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.boxplot(df['bedrooms'])
# Out:
# <Axes: ylabel='bedrooms'>

# %%
df['bedrooms'].min()
# Out:
# np.int64(0)

# %%
df['bedrooms'].max()
# Out:
# np.int64(6)

# %%
df['bedrooms'].mean()
# Out:
# np.float64(3.33)

# %%
df['bedrooms'].skew()
# Out:
# np.float64(0.3471725826280974)

# %% [markdown]
# ## d. Area_in_Marla

# %%
plt.hist(df['Area_in_Marla'])
# Out:
# (array([215., 180.,  35.,   3.,  59.,   3.,   1.,   1.,   2.,   1.]),
#  array([ 1. ,  5.7, 10.4, 15.1, 19.8, 24.5, 29.2, 33.9, 38.6, 43.3, 48. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.boxplot(df['Area_in_Marla'])
# Out:
# <Axes: ylabel='Area_in_Marla'>

# %%
df['Area_in_Marla'].min()
# Out:
# np.float64(1.0)

# %%
df['Area_in_Marla'].max()
# Out:
# np.float64(48.0)

# %%
df['Area_in_Marla'].mean()
# Out:
# np.float64(8.692200000000001)

# %%
df['Area_in_Marla'].skew()
# Out:
# np.float64(2.006811463334838)

# %% [markdown]
# ## Distplot (KDE)
